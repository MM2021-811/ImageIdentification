# %%
# !pip3 install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.8.0+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.9.0+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision) (8.1.2)

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch import nn
from torchvision import datasets, transforms, models
# from ..utils import _log_api_usage_once

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else "cpu")

# %%
transform_train = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomRotation(10),
                                      transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
                                      transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, ), (0.5, ))
                               ])


transform = transforms.Compose([transforms.Resize((224,224)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, ), (0.5, ))
                               ])

training_dataset = datasets.CIFAR100(root='./data', train=True, download=True, transform = transform_train)
validation_dataset = datasets.CIFAR100(root='./data', train=False, download=True, transform = transform)

training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=100, shuffle=True) # 100 tested
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=100, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def im_convert(tensor):
  image = tensor.cpu().clone().detach().numpy()
  image = image.transpose(1, 2, 0)
  image = image*np.array((0.5,0.5,0.5)) + np.array((0.5,0.5,0.5))
  image = image.clip(0,1)
  return image

# %%
classes = ['apples', 'aquarium fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottles', 
           'bowls', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'cans', 'castle', 'caterpillar', 'cattle', 'chair', 
           'chimpanzee', 'clock', 'cloud', 'cockroach', 'computer keyboard', 'couch', 'crab', 'crocodile', 
           'cups', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 
           'kangaroo', 'lamp', 'lawn-mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple', 'motorcycle', 
           'mountain', 'mouse', 'mushrooms', 'oak', 'oranges', 'orchids', 'otter', 'palm', 'pears', 'pickup truck', 
           'pine', 'plain', 'plates', 'poppies', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 
           'roses', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 
           'streetcar', 'sunflowers', 'sweet peppers', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
           'train', 'trout', 'tulips', 'turtle', 'wardrobe', 'whale', 'willow', 'wolf', 'woman', 'worm']

# %%
dataiter = iter(training_loader)
images, labels = dataiter.next()
fig = plt.figure(figsize = (25, 4))

for idx in np.arange(20):
  ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
  plt.imshow(im_convert(images[idx]))
  ax.set_title(classes[labels[idx].item()])

# %%
model = models.alexnet(pretrained=True)

# %%
for param in model.features.parameters():
  param.requires_grad = False

# %%
import torch.nn as nn
n_inputs = model.classifier[6].in_features
last_layer = nn.Linear(n_inputs, 100)
model.classifier[6] = last_layer
model.to(device)
print(model.classifier[6].out_features)
# Out:
# 100

# %%
for param in model.classifier[6].parameters():
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001) # lr = 0.001 tested

# %%
epochs = 45 # 15 epoch for 100 batch size tested
running_loss_history = []
running_corrects_history = []
val_running_loss_history = []
val_running_corrects_history = []

for e in range(epochs):

  running_loss = 0.0
  running_corrects = 0.0
  val_running_loss = 0.0
  val_running_corrects = 0.0

  for inputs, labels in training_loader:
    inputs = inputs.to(device)
    labels = labels.to(device)
    outputs = model(inputs)
    loss = criterion(outputs, labels)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    _, preds = torch.max(outputs, 1)
    running_loss += loss.item()
    running_corrects += torch.sum(preds == labels.data)


  else:
    with torch.no_grad():
     for val_inputs, val_labels in validation_loader:
      val_inputs = val_inputs.to(device)
      val_labels = val_labels.to(device)
      val_outputs = model(val_inputs)
      val_loss = criterion(val_outputs, val_labels)

      _, val_preds = torch.max(val_outputs, 1)
      val_running_loss += val_loss.item()
      val_running_corrects += torch.sum(val_preds == val_labels.data)


    epoch_loss = running_loss/len(training_loader)
    epoch_acc = running_corrects.float()/ len(training_loader)
    running_loss_history.append(epoch_loss)
    running_corrects_history.append(epoch_acc)

    val_epoch_loss = val_running_loss/len(validation_loader)
    val_epoch_acc = val_running_corrects.float()/ len(validation_loader)
    val_running_loss_history.append(val_epoch_loss)
    val_running_corrects_history.append(val_epoch_acc)

    print('epoch:', (e+1))
    print('training loss: {:.4f}, acc{:.4f}'.format(epoch_loss, epoch_acc.item()))
    print('validation loss: {:.4f}, validation acc{:.4f}'.format(val_epoch_loss, val_epoch_acc.item()))
# Out:
# epoch: 1
# training loss: 2.8853, acc28.3100
# validation loss: 2.0837, validation acc43.4400
# epoch: 2
# training loss: 2.2377, acc40.6340
# validation loss: 1.9442, validation acc47.3100
# epoch: 3
# training loss: 2.0575, acc44.7160
# validation loss: 1.8203, validation acc50.4100
# epoch: 4
# training loss: 1.9434, acc47.1880
# validation loss: 1.7514, validation acc51.9600
# epoch: 5
# training loss: 1.8631, acc48.9580
# validation loss: 1.7577, validation acc51.9300
# epoch: 6
# training loss: 1.7869, acc50.9140
# validation loss: 1.7040, validation acc53.2800
# epoch: 7
# training loss: 1.7329, acc52.1660
# validation loss: 1.6665, validation acc54.3000
# epoch: 8
# training loss: 1.6771, acc53.3660
# validation loss: 1.6706, validation acc54.3200
# epoch: 9
# training loss: 1.6324, acc54.8120
# validation loss: 1.6252, validation acc55.3400
# epoch: 10
# training loss: 1.5862, acc55.5080
# validation loss: 1.6357, validation acc55.5900
# epoch: 11
# training loss: 1.5407, acc56.5720
# validation loss: 1.6006, validation acc56.4200
# epoch: 12
# training loss: 1.5099, acc57.6160
# validation loss: 1.6282, validation acc55.9500
# epoch: 13
# training loss: 1.4650, acc58.4560
# validation loss: 1.6149, validation acc56.9300
# epoch: 14
# training loss: 1.4268, acc59.5160
# validation loss: 1.6357, validation acc55.8300
# epoch: 15
# training loss: 1.4017, acc60.3400
# validation loss: 1.6128, validation acc56.3200
# epoch: 16
# training loss: 1.3626, acc61.0640
# validation loss: 1.5995, validation acc57.0500
# epoch: 17
# training loss: 1.3369, acc61.6220
# validation loss: 1.6288, validation acc56.3200
# epoch: 18
# training loss: 1.2997, acc62.6660
# validation loss: 1.6102, validation acc57.2200
# epoch: 19
# training loss: 1.2747, acc63.3960
# validation loss: 1.6117, validation acc57.4100
# epoch: 20
# training loss: 1.2450, acc64.2100
# validation loss: 1.6189, validation acc57.6100
# epoch: 21
# training loss: 1.2312, acc64.4080
# validation loss: 1.6406, validation acc56.7000
# epoch: 22
# training loss: 1.1958, acc65.2680
# validation loss: 1.6407, validation acc57.8000
# epoch: 23
# training loss: 1.1755, acc65.6880
# validation loss: 1.6860, validation acc56.7000
# epoch: 24
# training loss: 1.1424, acc66.6680
# validation loss: 1.6576, validation acc57.4500
# epoch: 25
# training loss: 1.1238, acc67.0400
# validation loss: 1.6527, validation acc57.2400
# epoch: 26
# training loss: 1.1077, acc67.5760
# validation loss: 1.6763, validation acc56.9800
# epoch: 27
# training loss: 1.0864, acc68.2020
# validation loss: 1.6827, validation acc57.5600
# epoch: 28
# training loss: 1.0632, acc68.5920
# validation loss: 1.6899, validation acc57.0100
# epoch: 29
# training loss: 1.0445, acc69.1480
# validation loss: 1.6839, validation acc57.6200
# epoch: 30
# training loss: 1.0164, acc70.1080
# validation loss: 1.7126, validation acc56.8700
# epoch: 31
# training loss: 1.0102, acc69.8840
# validation loss: 1.7284, validation acc57.9900
# epoch: 32
# training loss: 0.9833, acc70.7760
# validation loss: 1.7601, validation acc57.3300
# epoch: 33
# training loss: 0.9697, acc71.0160
# validation loss: 1.7336, validation acc57.3100
# epoch: 34
# training loss: 0.9512, acc71.5280
# validation loss: 1.7432, validation acc57.3400
# epoch: 35
# training loss: 0.9297, acc72.0720
# validation loss: 1.7692, validation acc57.6500
# epoch: 36
# training loss: 0.9203, acc72.4900
# validation loss: 1.7862, validation acc57.1700
# epoch: 37
# training loss: 0.8973, acc73.2420
# validation loss: 1.8314, validation acc56.8800
# epoch: 38
# training loss: 0.8829, acc73.3700
# validation loss: 1.8400, validation acc57.0200
# epoch: 39
# training loss: 0.8638, acc73.8680
# validation loss: 1.7898, validation acc57.5900
# epoch: 40
# training loss: 0.8594, acc73.9160
# validation loss: 1.8026, validation acc57.8500
# epoch: 41
# training loss: 0.8419, acc74.4040
# validation loss: 1.8277, validation acc57.4300
# epoch: 42
# training loss: 0.8267, acc74.9180
# validation loss: 1.8382, validation acc57.7700
# epoch: 43
# training loss: 0.8099, acc75.3240
# validation loss: 1.8572, validation acc57.6400
# epoch: 44
# training loss: 0.7957, acc75.8040
# validation loss: 1.8717, validation acc56.8200
# epoch: 45
# training loss: 0.7915, acc76.0460
# validation loss: 1.8772, validation acc57.4500

# %%
plt.plot(running_loss_history, label = "training_loss")
plt.plot(val_running_loss_history, label = "validation_loss")
plt.legend()

# %%
plt.plot(running_corrects_history, label = "training_accuracy")
plt.plot(val_running_corrects_history, label = "validation_accuracy")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2453477/4053473183.py in <module>
# ----> 1 plt.plot(running_corrects_history, label = "training_accuracy")
#       2 plt.plot(val_running_corrects_history, label = "validation_accuracy")
#       3 plt.legend()
#
# /home/lihang/chenggui/ImageIdentification/.venv/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# /home/lihang/chenggui/ImageIdentification/.venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# /home/lihang/chenggui/ImageIdentification/.venv/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /home/lihang/chenggui/ImageIdentification/.venv/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     488             y = _check_1d(xy[1])
#     489         else:
# --> 490             x, y = index_of(xy[-1])
#     491
#     492         if self.axes.xaxis is not None:
#
# /home/lihang/chenggui/ImageIdentification/.venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in index_of(y)
#    1650         pass
#    1651     try:
# -> 1652         y = _check_1d(y)
#    1653     except (np.VisibleDeprecationWarning, ValueError):
#    1654         # NumPy 1.19 will warn on ragged input, and we can't actually use it.
#
# /home/lihang/chenggui/ImageIdentification/.venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _check_1d(x)
#    1302     """Convert scalars to 1D arrays; pass-through arrays as is."""
#    1303     if not hasattr(x, 'shape') or len(x.shape) < 1:
# -> 1304         return np.atleast_1d(x)
#    1305     else:
#    1306         try:
#
# <__array_function__ internals> in atleast_1d(*args, **kwargs)
#
# /home/lihang/chenggui/ImageIdentification/.venv/lib/python3.8/site-packages/numpy/core/shape_base.py in atleast_1d(*arys)
#      63     """
#      64     res = []
# ---> 65     for ary in arys:
#      66         ary = asanyarray(ary)
#      67         if ary.ndim == 0:
#
# /home/lihang/chenggui/ImageIdentification/.venv/lib/python3.8/site-packages/torch/tensor.py in __array__(self, dtype)
#     628             return handle_torch_function(Tensor.__array__, relevant_args, self, dtype=dtype)
#     629         if dtype is None:
# --> 630             return self.numpy()
#     631         else:
#     632             return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
